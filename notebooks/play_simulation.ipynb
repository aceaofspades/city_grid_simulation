# %%
import os, sys, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload

sys.path.append('..')

# %%
import city_block_simulation
reload(city_block_simulation)
from city_block_simulation import CityGrid, Corner, CityGridGame

# Play game
NUM_X_INTERSECTIONS = 7
NUM_Y_INTERSECTIONS = 4
game = CityGridGame(width=NUM_X_INTERSECTIONS, height=NUM_Y_INTERSECTIONS)
game.play()
# Out:
# Start position: (1, 1), End position: (12, 7)
# Current position: (1, 1)
# Valid moves: [(0, ((0, 1), 33)), (1, ((2, 1), 120)), (2, ((1, 0), 8)), (3, ((1, 2), 120))]
# chosen_move: 1
# type(chosen_move): <class 'int'>
# Valid move chosen.
# Move result: {'current_position': (2, 1), 'time_cost': 120, 'next_moves': [(0, ((1, 1), 120)), (1, ((3, 1), 8)), (2, ((2, 0), 29)), (3, ((2, 2), 120))]}
# Total time: 120
#
# Current position: (2, 1)
# Valid moves: [(0, ((1, 1), 120)), (1, ((3, 1), 8)), (2, ((2, 0), 29)), (3, ((2, 2), 120))]
# chosen_move: 1
# type(chosen_move): <class 'int'>
# Valid move chosen.
# Move result: {'current_position': (3, 1), 'time_cost': 8, 'next_moves': [(0, ((2, 1), 8)), (1, ((4, 1), 120)), (2, ((3, 0), 21)), (3, ((3, 2), 120))]}
# Total time: 128
#
# Current position: (3, 1)
# Valid moves: [(0, ((2, 1), 8)), (1, ((4, 1), 120)), (2, ((3, 0), 21)), (3, ((3, 2), 120))]
# chosen_move: 2
# type(chosen_move): <class 'int'>
# Valid move chosen.
# ...

# %%
# Repeat
